# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import SRW_v044 as SRW
from scipy.sparse import csr_matrix, csc_matrix, issparse
import functools

# %%
nsamples = 100
nnodes = 1000
edge_freq = 0.004
cliq_edge_freq = 0.114
hi_mut_freq = 0.5
hi_node = nnodes*3/4
group_labels = ['Subtype 1']*(nsamples/2) + ['Subtype 2']*(nsamples/2)
feature_names = ['Subnetwork 1', 'Subnetwork 2', 'High mut source', 'High mut target', 
                 'Random 1', 'Random 2', 
                 'Self loop', 'Intercept']
node_names = ['{}'.format(i) for i in range(1,nnodes+1)]
sample_names = ['{}'.format(i) for i in range(1,nsamples+1)]

rand_mut_freq = 0.015

# %%
rst_prob = 0.3
lam = 1e-1
WMW_b = 2e-4

# %%
degrees = [0]*nnodes
edges = []
features = [] #(11) cliq1, cliq2, hi_mut_source, hi_mut_target, rand1, rand2, rand3, rand4, rand5, self_loop, intercept
for i in range(nnodes-1):
    for j in range(i+1,nnodes):
        if ((i<100 and j<100) and np.random.random()<cliq_edge_freq) or np.random.random()<edge_freq:
            edges.append([i,j])
            edges.append([j,i])
            features.append([0,0,0,0,np.random.random(),np.random.random(),0,1])
            features.append([0,0,0,0,np.random.random(),np.random.random(),0,1])
            if (i<50 and j<50):
                features[-2][0] = 1
                features[-1][0] = 1
            if (i>=50 and i<100 and j>=50 and j<100):
                features[-2][1] = 1
                features[-1][1] = 1
            if i == nnodes-1:
                features[-2][2] = 1
                features[-1][3] = 1
            if j == nnodes-1:
                features[-2][3] = 1
                features[-1][2] = 1
            degrees[i] += 1
            degrees[j] += 1

for i in range(nnodes):
    edges.append([i,i])
    features.append([0,0,0,0,np.random.random(),np.random.random(),1,1])

P_init = []
for p in range(nsamples):
    p_init = []
    for i in range(nnodes):
        freq=0
        if p == i:
            freq = 1
        elif i == hi_node:
            freq = hi_mut_freq
        elif i<100:
            if (max(p,i)<50 or min(p,i)>=50):
                freq = 0.015
            else:
                freq = 0.000
        else:
            freq = rand_mut_freq

        if np.random.random() < freq:
            p_init.append(1)
        else:
            p_init.append(0)

    P_init.append(p_init)

edges = np.array(edges)
features = csc_matrix(features)
P_init = csr_matrix(P_init)

SRW_obj = SRW.SRW_solver(edges, features, nnodes, P_init, rst_prob, group_labels, lam, w_init_sd=0.01, 
                         w=None, feature_names=feature_names, sample_names=sample_names, 
                         node_names=node_names, loss='WMW', norm_type='L1', learning_rate=0.5, 
                         update_w_func='Adam', P_init_val=P_init, group_labels_val=group_labels, 
                         ncpus=len(feature_names), maxit=1000, early_stop=10, WMW_b=WMW_b)

SRW_obj.train_SRW_GD()
# Out:
# finished calculating strength_grad: 15:58:05
# finished network propagation: 15:58:05
# finished calculating P_grad using pool: 15:58:07
# finished calculating J and J_grad: 15:58:07
# *** 0 iteration: J is 51.8838897295 cost_val is 11.4812366422
# *** accuracy is 0.52 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:08
# finished network propagation: 15:58:09
# finished calculating P_grad using pool: 15:58:11
# finished calculating J and J_grad: 15:58:11
# *** 1 iteration: J is 51.0985059017 cost_val is 12.075110222
# *** accuracy is 0.53 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:12
# finished network propagation: 15:58:13
# finished calculating P_grad using pool: 15:58:14
# finished calculating J and J_grad: 15:58:15
# *** 2 iteration: J is 49.3141091454 cost_val is 12.355458211
# *** accuracy is 0.57 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:17
# finished network propagation: 15:58:19
# finished calculating P_grad using pool: 15:58:20
# finished calculating J and J_grad: 15:58:20
# *** 3 iteration: J is 46.6807768334 cost_val is 11.7882571546
# *** accuracy is 0.61 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:21
# finished network propagation: 15:58:23
# finished calculating P_grad using pool: 15:58:25
# finished calculating J and J_grad: 15:58:25
# *** 4 iteration: J is 43.3198270098 cost_val is 10.5941925115
# *** accuracy is 0.67 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:58:26
# finished network propagation: 15:58:27
# finished calculating P_grad using pool: 15:58:29
# finished calculating J and J_grad: 15:58:29
# *** 5 iteration: J is 39.5177889466 cost_val is 9.25192918458
# *** accuracy is 0.73 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:58:31
# finished network propagation: 15:58:32
# finished calculating P_grad using pool: 15:58:34
# finished calculating J and J_grad: 15:58:34
# *** 6 iteration: J is 35.3969845204 cost_val is 8.0018622588
# *** accuracy is 0.76 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:36
# finished network propagation: 15:58:37
# finished calculating P_grad using pool: 15:58:38
# finished calculating J and J_grad: 15:58:38
# *** 7 iteration: J is 31.4082495397 cost_val is 6.94302044151
# *** accuracy is 0.8 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:39
# finished network propagation: 15:58:40
# finished calculating P_grad using pool: 15:58:41
# finished calculating J and J_grad: 15:58:42
# *** 8 iteration: J is 28.1214637507 cost_val is 6.14235388848
# *** accuracy is 0.83 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:44
# finished network propagation: 15:58:45
# finished calculating P_grad using pool: 15:58:46
# finished calculating J and J_grad: 15:58:46
# *** 9 iteration: J is 25.727785247 cost_val is 5.5948407071
# *** accuracy is 0.85 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:48
# finished network propagation: 15:58:49
# finished calculating P_grad using pool: 15:58:50
# finished calculating J and J_grad: 15:58:51
# *** 10 iteration: J is 24.1316613587 cost_val is 5.24113055055
# *** accuracy is 0.87 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:51
# finished network propagation: 15:58:52
# finished calculating P_grad using pool: 15:58:54
# finished calculating J and J_grad: 15:58:54
# *** 11 iteration: J is 23.09980363 cost_val is 5.01452373651
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:54
# finished network propagation: 15:58:55
# finished calculating P_grad using pool: 15:58:56
# finished calculating J and J_grad: 15:58:56
# *** 12 iteration: J is 22.4297292445 cost_val is 4.8660180041
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:58:57
# finished network propagation: 15:58:58
# finished calculating P_grad using pool: 15:59:00
# finished calculating J and J_grad: 15:59:00
# *** 13 iteration: J is 22.0144077604 cost_val is 4.7654944913
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:01
# finished network propagation: 15:59:02
# finished calculating P_grad using pool: 15:59:04
# finished calculating J and J_grad: 15:59:04
# *** 14 iteration: J is 21.8215475293 cost_val is 4.69480548982
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:05
# finished network propagation: 15:59:06
# finished calculating P_grad using pool: 15:59:08
# finished calculating J and J_grad: 15:59:08
# *** 15 iteration: J is 21.7170300763 cost_val is 4.64330116433
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:09
# finished network propagation: 15:59:09
# finished calculating P_grad using pool: 15:59:11
# finished calculating J and J_grad: 15:59:11
# *** 16 iteration: J is 21.6665220526 cost_val is 4.60268286663
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:13
# finished network propagation: 15:59:15
# finished calculating P_grad using pool: 15:59:16
# finished calculating J and J_grad: 15:59:17
# *** 17 iteration: J is 21.6280347381 cost_val is 4.56712078202
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:19
# finished network propagation: 15:59:20
# finished calculating P_grad using pool: 15:59:21
# finished calculating J and J_grad: 15:59:22
# *** 18 iteration: J is 21.5866433369 cost_val is 4.5326821984
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:59:22
# finished network propagation: 15:59:23
# finished calculating P_grad using pool: 15:59:25
# finished calculating J and J_grad: 15:59:25
# *** 19 iteration: J is 21.5597078356 cost_val is 4.49635629897
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:59:26
# finished network propagation: 15:59:27
# finished calculating P_grad using pool: 15:59:29
# finished calculating J and J_grad: 15:59:29
# *** 20 iteration: J is 21.541751574 cost_val is 4.45698476004
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:59:30
# finished network propagation: 15:59:31
# finished calculating P_grad using pool: 15:59:32
# finished calculating J and J_grad: 15:59:33
# *** 21 iteration: J is 21.5135615001 cost_val is 4.41417458526
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:59:34
# finished network propagation: 15:59:37
# finished calculating P_grad using pool: 15:59:38
# finished calculating J and J_grad: 15:59:38
# *** 22 iteration: J is 21.4812779101 cost_val is 4.36841344381
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:59:39
# finished network propagation: 15:59:40
# finished calculating P_grad using pool: 15:59:41
# finished calculating J and J_grad: 15:59:41
# *** 23 iteration: J is 21.4400453355 cost_val is 4.32202892302
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 15:59:43
# finished network propagation: 15:59:45
# finished calculating P_grad using pool: 15:59:46
# finished calculating J and J_grad: 15:59:46
# *** 24 iteration: J is 21.387849045 cost_val is 4.27755166275
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:48
# finished network propagation: 15:59:48
# finished calculating P_grad using pool: 15:59:50
# finished calculating J and J_grad: 15:59:50
# *** 25 iteration: J is 21.3577035251 cost_val is 4.23713024713
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:52
# finished network propagation: 15:59:53
# finished calculating P_grad using pool: 15:59:54
# finished calculating J and J_grad: 15:59:54
# *** 26 iteration: J is 21.3264352664 cost_val is 4.20364228334
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 15:59:55
# finished network propagation: 15:59:58
# finished calculating P_grad using pool: 15:59:59
# finished calculating J and J_grad: 15:59:59
# *** 27 iteration: J is 21.2932410208 cost_val is 4.1803343381
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:00
# finished network propagation: 16:00:00
# finished calculating P_grad using pool: 16:00:02
# finished calculating J and J_grad: 16:00:02
# *** 28 iteration: J is 21.2691697352 cost_val is 4.16772229568
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:04
# finished network propagation: 16:00:05
# finished calculating P_grad using pool: 16:00:07
# finished calculating J and J_grad: 16:00:07
# *** 29 iteration: J is 21.233376715 cost_val is 4.16342261338
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:07
# finished network propagation: 16:00:08
# finished calculating P_grad using pool: 16:00:10
# finished calculating J and J_grad: 16:00:10
# *** 30 iteration: J is 21.2017238435 cost_val is 4.16512947036
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:12
# finished network propagation: 16:00:12
# finished calculating P_grad using pool: 16:00:14
# finished calculating J and J_grad: 16:00:14
# *** 31 iteration: J is 21.1547264399 cost_val is 4.17005397749
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:16
# finished network propagation: 16:00:16
# finished calculating P_grad using pool: 16:00:18
# finished calculating J and J_grad: 16:00:18
# *** 32 iteration: J is 21.0971407792 cost_val is 4.17548615906
# *** accuracy is 0.9 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:20
# finished network propagation: 16:00:20
# finished calculating P_grad using pool: 16:00:22
# finished calculating J and J_grad: 16:00:22
# *** 33 iteration: J is 21.0305092175 cost_val is 4.1811299478
# *** accuracy is 0.9 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:22
# finished network propagation: 16:00:23
# finished calculating P_grad using pool: 16:00:24
# finished calculating J and J_grad: 16:00:25
# *** 34 iteration: J is 20.9676905476 cost_val is 4.18559614248
# *** accuracy is 0.9 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:25
# finished network propagation: 16:00:26
# finished calculating P_grad using pool: 16:00:27
# finished calculating J and J_grad: 16:00:28
# *** 35 iteration: J is 20.9046732389 cost_val is 4.18621994353
# *** accuracy is 0.9 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:28
# finished network propagation: 16:00:29
# finished calculating P_grad using pool: 16:00:30
# finished calculating J and J_grad: 16:00:30
# *** 36 iteration: J is 20.8368032095 cost_val is 4.1827040864
# *** accuracy is 0.9 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:31
# finished network propagation: 16:00:32
# finished calculating P_grad using pool: 16:00:33
# finished calculating J and J_grad: 16:00:33
# *** 37 iteration: J is 20.7669279725 cost_val is 4.17675042549
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:34
# finished network propagation: 16:00:34
# finished calculating P_grad using pool: 16:00:36
# finished calculating J and J_grad: 16:00:36
# *** 38 iteration: J is 20.6984190888 cost_val is 4.16670998166
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:37
# finished network propagation: 16:00:37
# finished calculating P_grad using pool: 16:00:39
# finished calculating J and J_grad: 16:00:39
# *** 39 iteration: J is 20.6519524029 cost_val is 4.15300816369
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:40
# finished network propagation: 16:00:40
# finished calculating P_grad using pool: 16:00:41
# finished calculating J and J_grad: 16:00:42
# *** 40 iteration: J is 20.6035058619 cost_val is 4.13767388522
# *** accuracy is 0.89 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 16:00:42
# finished network propagation: 16:00:42
# finished calculating P_grad using pool: 16:00:44
# finished calculating J and J_grad: 16:00:44
# *** 41 iteration: J is 20.5676764055 cost_val is 4.11944596937
# *** accuracy is 0.89 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 16:00:46
# finished network propagation: 16:00:47
# finished calculating P_grad using pool: 16:00:49
# finished calculating J and J_grad: 16:00:49
# *** 42 iteration: J is 20.542711872 cost_val is 4.0987978516
# *** accuracy is 0.89 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 16:00:50
# finished network propagation: 16:00:50
# finished calculating P_grad using pool: 16:00:52
# finished calculating J and J_grad: 16:00:52
# *** 43 iteration: J is 20.5092289509 cost_val is 4.07740095825
# *** accuracy is 0.88 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:53
# finished network propagation: 16:00:54
# finished calculating P_grad using pool: 16:00:56
# finished calculating J and J_grad: 16:00:56
# *** 44 iteration: J is 20.4990391618 cost_val is 4.05512350964
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:00:57
# finished network propagation: 16:00:58
# finished calculating P_grad using pool: 16:00:59
# finished calculating J and J_grad: 16:00:59
# *** 45 iteration: J is 20.4875030329 cost_val is 4.03110742968
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:00
# finished network propagation: 16:01:01
# finished calculating P_grad using pool: 16:01:02
# finished calculating J and J_grad: 16:01:02
# *** 46 iteration: J is 20.4688522006 cost_val is 4.00623200175
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:05
# finished network propagation: 16:01:07
# finished calculating P_grad using pool: 16:01:09
# finished calculating J and J_grad: 16:01:09
# *** 47 iteration: J is 20.4415768131 cost_val is 3.9817656199
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:12
# finished network propagation: 16:01:13
# finished calculating P_grad using pool: 16:01:15
# finished calculating J and J_grad: 16:01:15
# *** 48 iteration: J is 20.4247386651 cost_val is 3.95934115262
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:16
# finished network propagation: 16:01:17
# finished calculating P_grad using pool: 16:01:19
# finished calculating J and J_grad: 16:01:19
# *** 49 iteration: J is 20.4079962725 cost_val is 3.94058050001
# *** accuracy is 0.88 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:20
# finished network propagation: 16:01:22
# finished calculating P_grad using pool: 16:01:23
# finished calculating J and J_grad: 16:01:24
# *** 50 iteration: J is 20.3763054475 cost_val is 3.92758416187
# *** accuracy is 0.88 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:25
# finished network propagation: 16:01:26
# finished calculating P_grad using pool: 16:01:28
# finished calculating J and J_grad: 16:01:28
# *** 51 iteration: J is 20.3231301061 cost_val is 3.92053786393
# *** accuracy is 0.88 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:29
# finished network propagation: 16:01:30
# finished calculating P_grad using pool: 16:01:31
# finished calculating J and J_grad: 16:01:31
# *** 52 iteration: J is 20.2626914899 cost_val is 3.91862646498
# *** accuracy is 0.9 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:32
# finished network propagation: 16:01:34
# finished calculating P_grad using pool: 16:01:36
# finished calculating J and J_grad: 16:01:36
# *** 53 iteration: J is 20.2209938151 cost_val is 3.91970285266
# *** accuracy is 0.9 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 16:01:38
# finished network propagation: 16:01:40
# finished calculating P_grad using pool: 16:01:42
# finished calculating J and J_grad: 16:01:42
# *** 54 iteration: J is 20.1636122321 cost_val is 3.92236228041
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:01:44
# finished network propagation: 16:01:45
# finished calculating P_grad using pool: 16:01:47
# finished calculating J and J_grad: 16:01:47
# *** 55 iteration: J is 20.0926708351 cost_val is 3.92527256753
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:01:48
# finished network propagation: 16:01:49
# finished calculating P_grad using pool: 16:01:50
# finished calculating J and J_grad: 16:01:50
# *** 56 iteration: J is 20.0116812669 cost_val is 3.92744475279
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:01:53
# finished network propagation: 16:01:55
# finished calculating P_grad using pool: 16:01:57
# finished calculating J and J_grad: 16:01:57
# *** 57 iteration: J is 19.9428262404 cost_val is 3.92829339393
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:02:01
# finished network propagation: 16:02:03
# finished calculating P_grad using pool: 16:02:05
# finished calculating J and J_grad: 16:02:05
# *** 58 iteration: J is 19.8709254464 cost_val is 3.92852825475
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:02:08
# finished network propagation: 16:02:10
# finished calculating P_grad using pool: 16:02:12
# finished calculating J and J_grad: 16:02:12
# *** 59 iteration: J is 19.811935038 cost_val is 3.92819795635
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:02:14
# finished network propagation: 16:02:15
# finished calculating P_grad using pool: 16:02:16
# finished calculating J and J_grad: 16:02:17
# *** 60 iteration: J is 19.7471860812 cost_val is 3.92744988013
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:02:19
# finished network propagation: 16:02:20
# finished calculating P_grad using pool: 16:02:22
# finished calculating J and J_grad: 16:02:22
# *** 61 iteration: J is 19.704113218 cost_val is 3.92644250431
# *** accuracy is 0.91 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:02:23
# finished network propagation: 16:02:24
# finished calculating P_grad using pool: 16:02:26
# finished calculating J and J_grad: 16:02:26
# *** 62 iteration: J is 19.6716126759 cost_val is 3.92462691735
# *** accuracy is 0.91 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 16:02:27
# finished network propagation: 16:02:30
# finished calculating P_grad using pool: 16:02:32
# finished calculating J and J_grad: 16:02:32
# *** 63 iteration: J is 19.6427161419 cost_val is 3.92237746216
# *** accuracy is 0.91 accuracy_val is 0.98

# %%
SRW_obj.w_map
# Out:
#                     Weight
# Subnetwork 1      8.178438
# Subnetwork 2      8.490222
# High mut source   0.004118
# High mut target  -0.063055
# Random 1          4.047448
# Random 2         -2.219268
# Self loop        -2.293991
# Intercept       -13.409882

# %%
import numpy as np
import pyNBS
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SRW_obj.w = SRW_obj.w_list[0]
SRW_obj.map_w()
SRW_obj.w[-1] = 100
SRW_obj.w[-2] = -200
SRW_obj.Q = SRW.generate_Q(SRW_obj.edges, SRW_obj.nnodes, SRW_obj.features, SRW_obj.w)
P = SRW.iterative_PPR(SRW_obj.Q.toarray(), SRW.renorm(SRW_obj.P_init).toarray(), SRW_obj.rst_prob)
SRW_obj.C = SRW_obj.centroid(P, SRW_obj.ngroups, SRW_obj.group2indeces_list)
SRW_obj.calc_cost_and_acc_val()
SRW_obj.generate_Q_and_P_fin()

# %%
P_df = SRW_obj.P_fin_df.copy()
P_df_pca, pca_components, explained_variance_ratio = pyNBS.run_pca(P_df)

# %%
X = P_df_pca.copy()
X['labels'] = group_labels

labels = X.groupby('labels')

cmap = plt.get_cmap('jet')
colors = cmap(np.linspace(0, 1.0, len(labels)))

fig, ax = plt.subplots(figsize=(7, 7))
ax.set_color_cycle(colors)
for name, label in labels:
    ax.plot(label.PC1, label.PC2, alpha=0.5, marker='o', linestyle='', label=name)

plt.xlabel('Component 1')
plt.ylabel('Component 2')
ax.legend(loc='upper right')

plt.savefig('data/sim1001000_0_PCA.pdf')
plt.show()

# %%
SRW_obj.w = SRW_obj.w_list[-1]
SRW_obj.map_w()
SRW_obj.Q = SRW.generate_Q(SRW_obj.edges, SRW_obj.nnodes, SRW_obj.features, SRW_obj.w)
P = SRW.iterative_PPR(SRW_obj.Q.toarray(), SRW.renorm(SRW_obj.P_init).toarray(), SRW_obj.rst_prob)
SRW_obj.C = SRW_obj.centroid(P, SRW_obj.ngroups, SRW_obj.group2indeces_list)
SRW_obj.calc_cost_and_acc_val()
SRW_obj.generate_Q_and_P_fin()

P_df = SRW_obj.P_fin_df.copy()
P_df_pca, pca_components, explained_variance_ratio = pyNBS.run_pca(P_df)

X = P_df_pca.copy()
X['labels'] = group_labels

labels = X.groupby('labels')

cmap = plt.get_cmap('jet')
colors = cmap(np.linspace(0, 1.0, len(labels)))

fig, ax = plt.subplots(figsize=(7, 7))
ax.set_color_cycle(colors)
for name, label in labels:
    ax.plot(label.PC1, label.PC2, alpha=0.5, marker='o', linestyle='', label=name)

plt.xlabel('Component 1')
plt.ylabel('Component 2')
ax.legend(loc='upper right')

plt.savefig('data/sim1001000_-1_PCA.pdf')

plt.show()

# %%
P_df
# Out:
#             1         2         3         4         5         6         7  \
# 1    0.022336  0.003366  0.000658  0.003904  0.005009  0.006132  0.000433
# 2    0.007230  0.028185  0.000568  0.007266  0.003778  0.000669  0.000290
# 3    0.001071  0.001344  0.018573  0.001056  0.005287  0.002816  0.000740
# 4    0.013180  0.006648  0.002626  0.020802  0.010672  0.000119  0.000589
# 5    0.004973  0.013154  0.002793  0.004273  0.034344  0.000574  0.002421
# 6    0.012969  0.004777  0.002519  0.004417  0.013402  0.023559  0.001255
# 7    0.006080  0.005376  0.001181  0.011406  0.001686  0.000167  0.034880
# 8    0.002459  0.003673  0.000387  0.003769  0.003270  0.001157  0.001038
# 9    0.001773  0.001556  0.002409  0.001311  0.005536  0.000761  0.001174
# 10   0.002845  0.005098  0.000447  0.004184  0.003415  0.002448  0.000754
# 11   0.006561  0.007370  0.002835  0.009919  0.010091  0.000234  0.023886
# 12   0.002654  0.002911  0.000946  0.001723  0.007039  0.000164  0.002103
# 13   0.002483  0.003763  0.000628  0.003801  0.005386  0.002647  0.000457
# 14   0.001261  0.001870  0.003920  0.001579  0.001685  0.000968  0.001353
# 15   0.002384  0.006322  0.001061  0.003583  0.002104  0.000914  0.003918
# 16   0.001257  0.003302  0.000864  0.001728  0.001795  0.000180  0.002026
# 17   0.003708  0.030807  0.002946  0.005298  0.006595  0.000629  0.002013
# 18   0.001030  0.001176  0.001101  0.001224  0.001735  0.000170  0.000374
# 19   0.002142  0.002935  0.000767  0.002651  0.005947  0.000126  0.003999
# 20   0.001983  0.002640  0.000560  0.002816  0.005132  0.000717  0.000504
# 21   0.001927  0.002114  0.000448  0.002970  0.001576  0.000264  0.006649
# 22   0.002014  0.003963  0.002355  0.002474  0.009565  0.002636  0.001853
# 23   0.002628  0.010347  0.000319  0.003629  0.001795  0.000521  0.000422
# 24   0.004459  0.004352  0.001587  0.007670  0.002732  0.001179  0.001052
