# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import SRW_v041 as SRW
import pickle

# %%
edges, features, node_names = SRW.load_network('data/BRCA_edge2features.txt')
# Out:
# * Loading network...

# %%
P_init_train, sample_names_train = SRW.load_samples('data/BRCA_training_data.txt', node_names)
# Out:
# 	- Nodes in adjacency matrix: 17557

# %%
P_init_val, sample_names_val = SRW.load_samples('data/BRCA_validation_data.txt', node_names)
# Out:
# 	- Nodes in adjacency matrix: 17557

# %%
group_labels_train = SRW.load_grouplabels('data/BRCA_training_lables.txt')

# %%
group_labels_val = SRW.load_grouplabels('data/BRCA_validation_lables.txt')

# %%
nnodes = len(node_names)
rst_prob = 0.3
lam = 1e-8
w_init_sd = 0.01

# %%
feature_names = []
with open('data/BRCA_feature_names.txt') as f:
    for line in f.read().rstrip().splitlines():
        feature_names.append(line)
feature_names.append('selfloop')
feature_names.append('intercept')

# %%
SRW_obj = SRW.SRW_solver(edges, features, nnodes, P_init_train, rst_prob, group_labels_train, lam, 
                         w_init_sd=0.01, w=None, feature_names=feature_names, sample_names=sample_names_train, 
                         node_names=node_names, loss='centroid', norm_type='L2', maximize_diff=False, 
                         learning_rate=1., update_w_func='Adam', P_init_val=P_init_val, 
                         group_labels_val=group_labels_val, eval_sil=True, ncpus=1)

# %% [markdown]
# ### Arguments of SRW_solver objects
# **edges** (e by 2, int, ndarray): Edges in the network
# **features** (e by w, float, csc_matrix): Edge features
# **nnodes** (int): Number of nodes in the network
# **P_init** (m by n, float, csr_matrix): Initial state of samples (training set)
# **rst_prob** (float): Reset probability of random walk
# **group_labels** (m by 1, str/int, list): Group labels of samples (training set)
# **lam** (float): Regularization parameter, controling the amount of L1/L2 norm
# **w_init_sd** (float): Standard deviation for weight initialization (default 0.01)
# **w** (w by 1, float, list): Initial weights (default None)
# **feature_names** (w by 1, str, list): Feature names (default [])
# **sample_names** (m by 1, str, list): Feature names (default [])
# **node_names** (n by 1, str, list): Feature names (default [])
# **loss** ('squared', 'absolute', 'centroid', 'silhouette'): Type of the loss funtion (default 'squared')
# **norm_type** ('L1', 'L2'): Type of the norm (derault 'L2')
# **maximize_diff** (bool): Whether to maximaze the difference between groups (default False)
# **learning_rate** (float): Learning rate (default 0.1)
# **update_w_func** ('momentum', 'Nesterov', 'Adam', 'Nadam'): Function for updating parameters (default 'Adam')
# **P_init_val** (m by n, float, csr_matrix): Initial state of samples (validation set) (default None)
# **group_labels_val** (m by 1, str/int, list): Group labels of samples (validation set) (default None)
# **eval_sil** (bool): Whether to evaluate silhouette width (default: False)
# **ncpus** (int): Number of CPUs to use for multiprocess.Pool (default: -1, use all cpus)

# %%
SRW_obj.train_SRW_GD()

# %% [markdown]
# # Scratch

# %%
SRW_obj.init_w()
SRW_obj.map_w()
SRW_obj.w_map
# Out:
#                                              Weight
# Adherens junction                          0.004322
# Apoptosis                                  0.010622
# B cell receptor signaling pathway          0.008194
# BIND                                      -0.006660
# Base excision repair                      -0.013622
# BioGRID                                   -0.010996
# CORUM                                     -0.002976
# CTD                                        0.007315
# Cell cycle                                 0.002697
# Cytokine-cytokine receptor interaction    -0.006396
# DIP                                       -0.005241
# ECM-receptor interaction                   0.001741
# ESC proliferation                          0.013160
# Epithelial-mesenchymal transition         -0.008116
# ErbB signaling pathway                    -0.005450
# Focal adhesion                             0.002511
# Glycolysis / Gluconeogenesis              -0.004353
# HPRD                                      -0.002913
# HumanCyc                                  -0.003819
# INOH                                      -0.006244
# IntAct                                    -0.002188
# Jak-STAT signaling pathway                -0.007346
# KEGG                                      -0.006147
# MAPK signaling pathway                     0.005032
# MSigDB                                    -0.015802
# Mismatch repair                            0.009278
# Multi-Drug Resistance Factors              0.013576
# Natural killer cell mediated cytotoxicity  0.013746
# NetPath                                    0.014112
# Nucleotide excision repair                 0.021366
# ...                                             ...
# Reactome                                   0.009122
# Recon X                                    0.006084
# SMPDB                                      0.013457
# T cell receptor signaling pathway         -0.003541
# TGF-beta signaling pathway                -0.003155
# VEGF signaling pathway                    -0.004370
# WikiPathways                              -0.010944
# Wnt signaling pathway                     -0.028443
# catalysis-precedes                        -0.005718
# catalysis-precedes_directed               -0.004191
# controls-expression-of                    -0.005773
# controls-expression-of_directed           -0.006285
# controls-phosphorylation-of                0.004985
# controls-phosphorylation-of_directed      -0.002939
# controls-state-change-of                  -0.007185
# controls-state-change-of_directed          0.010954
# controls-transport-of                      0.007334
# controls-transport-of_directed            -0.014435
# in-complex-with                           -0.000403
# inflammatory response                     -0.001074
# interacts-with                            -0.007815
# mTOR signaling pathway                    -0.004974
# mutrate_source                             0.006684
# mutrate_target                            -0.010113
# mutual_exclusive                           0.012277
# p53 signaling pathway                      0.005533
# pid                                       -0.000449
# telomere maintenance                       0.015611
# selfloop                                   0.003168
# intercept                                 -0.003434
#
# [64 rows x 1 columns]

# %%
SRW_obj.init_w()
SRW_obj.generate_Q_and_P_fin()

# %%
with open('data/SRW_obj_3') as f:
    SRW_obj = pickle.load(f)

# %%
SRW_obj.w_map.Weight.sort_values()
# Out:
# controls-expression-of_directed             -9.308106
# selfloop                                    -3.489996
# intercept                                   -3.150205
# mutrate_target                              -0.500697
# Epithelial-mesenchymal transition           -0.156851
# Natural killer cell mediated cytotoxicity   -0.151249
# B cell receptor signaling pathway           -0.108847
# ESC proliferation                           -0.088785
# KEGG                                        -0.055768
# Apoptosis                                   -0.053781
# mutual_exclusive                            -0.028445
# telomere maintenance                        -0.027874
# Cytokine-cytokine receptor interaction      -0.025206
# Mismatch repair                             -0.023935
# controls-phosphorylation-of_directed        -0.010669
# PPAR signaling pathway                      -0.006356
# Focal adhesion                              -0.004227
# mTOR signaling pathway                      -0.003195
# VEGF signaling pathway                      -0.000287
# Multi-Drug Resistance Factors                0.000343
# Glycolysis / Gluconeogenesis                 0.006282
# Base excision repair                         0.010002
# WikiPathways                                 0.022786
# NetPath                                      0.027345
# SMPDB                                        0.028873
# p53 signaling pathway                        0.032596
# controls-transport-of_directed               0.035177
# PhosphoSite                                  0.038924
# ECM-receptor interaction                     0.045037
# Recon X                                      0.054223
#                                                ...
# Cell cycle                                   0.113844
# inflammatory response                        0.128562
# ErbB signaling pathway                       0.152542
# Reactome                                     0.169583
# Jak-STAT signaling pathway                   0.217717
# T cell receptor signaling pathway            0.232499
# CORUM                                        0.232849
# Adherens junction                            0.288341
# Wnt signaling pathway                        0.307527
# PANTHER                                      0.370576
# DIP                                          0.443912
# HumanCyc                                     0.468990
# pid                                          0.572120
# MAPK signaling pathway                       0.798072
# catalysis-precedes_directed                  0.899577
# controls-transport-of                        0.935926
# HPRD                                         1.004078
# controls-state-change-of_directed            1.111036
# Pathways in cancer                           1.149128
# BioGRID                                      1.369817
# IntAct                                       1.682376
# TGF-beta signaling pathway                   1.829760
# BIND                                         1.834586
# controls-state-change-of                     1.868491
# catalysis-precedes                           1.942952
# interacts-with                               2.101940
# in-complex-with                              2.258056
# MSigDB                                       2.655952
# controls-expression-of                       2.670770
# CTD                                          2.671493
# Name: Weight, Length: 64, dtype: float64

# %%
SRW_obj.generate_Q_and_P_fin()

# %%
SRW_obj.P_fin_df
# Out:
#                   A1BG      A1CF       A2M     A2ML1    A4GALT     A4GNT  \
# TCGA-A1-A0SD  0.000033  0.000021  0.000086  0.000002  0.000011  0.000019
# TCGA-A1-A0SH  0.000031  0.000014  0.000091  0.000001  0.000024  0.000081
# TCGA-A1-A0SJ  0.000042  0.000020  0.000089  0.000003  0.000035  0.000010
# TCGA-A1-A0SM  0.000032  0.000016  0.000078  0.000002  0.000012  0.000005
# TCGA-A1-A0SN  0.000034  0.000016  0.000089  0.000001  0.000023  0.000077
# TCGA-A1-A0SQ  0.000027  0.000022  0.000092  0.000002  0.000028  0.000024
# TCGA-A2-A04N  0.000038  0.000027  0.000127  0.000002  0.000029  0.000028
# TCGA-A2-A04P  0.000038  0.000017  0.000136  0.000002  0.000013  0.000006
# TCGA-A2-A04R  0.000038  0.000104  0.000097  0.000002  0.000012  0.000006
# TCGA-A2-A04U  0.000041  0.000034  0.000180  0.000001  0.000020  0.000008
# TCGA-A2-A04W  0.000031  0.000018  0.000078  0.000001  0.000020  0.000074
# TCGA-A2-A04X  0.000028  0.000016  0.000154  0.000001  0.000034  0.000013
# TCGA-A2-A0CK  0.000034  0.000018  0.000789  0.000001  0.000019  0.000006
# TCGA-A2-A0CM  0.000030  0.000031  0.000091  0.000001  0.000027  0.000008
# TCGA-A2-A0CS  0.000044  0.000014  0.000076  0.000002  0.000024  0.000005
# TCGA-A2-A0CU  0.000038  0.000029  0.000184  0.000002  0.000019  0.000024
# TCGA-A2-A0CW  0.000032  0.000016  0.000081  0.000002  0.000012  0.000005
# TCGA-A2-A0CX  0.000030  0.000016  0.000110  0.000002  0.000020  0.000007
# TCGA-A2-A0D0  0.000040  0.000020  0.000098  0.000005  0.000064  0.000030
# TCGA-A2-A0D1  0.000029  0.000018  0.000138  0.000001  0.000022  0.000043
# TCGA-A2-A0D3  0.000043  0.000020  0.000071  0.000001  0.000013  0.000250
# TCGA-A2-A0D4  0.000032  0.000017  0.000091  0.000001  0.000029  0.000012
# TCGA-A2-A0EM  0.000045  0.000023  0.000224  0.000003  0.000022  0.000050
# TCGA-A2-A0EN  0.000037  0.000017  0.000082  0.000007  0.000061  0.000166
# TCGA-A2-A0EO  0.000256  0.000017  0.000102  0.000001  0.000013  0.000006
# TCGA-A2-A0EQ  0.000033  0.000081  0.000314  0.000002  0.000023  0.000062
# TCGA-A2-A0ER  0.000054  0.000019  0.000088  0.000001  0.000041  0.000234
# TCGA-A2-A0ES  0.000035  0.000023  0.000088  0.000001  0.000019  0.000089
# TCGA-A2-A0EU  0.000048  0.000018  0.000096  0.000001  0.000029  0.000008
# TCGA-A2-A0EV  0.000038  0.000020  0.000119  0.000002  0.000023  0.000010
# ...                ...       ...       ...       ...       ...       ...
# TCGA-EW-A2FS  0.000034  0.000015  0.000085  0.000002  0.000044  0.000148
# TCGA-EW-A2FV  0.000037  0.000015  0.000081  0.000001  0.000014  0.000006
# TCGA-EW-A2FW  0.000032  0.000025  0.000077  0.000001  0.000031  0.000010
# TCGA-EW-A3E8  0.000054  0.000020  0.000093  0.000001  0.000057  0.000008
# TCGA-EW-A3U0  0.000031  0.000015  0.000074  0.000002  0.000014  0.000005
# TCGA-GI-A2C8  0.000044  0.000023  0.000157  0.000001  0.000048  0.000027
# TCGA-GI-A2C9  0.000036  0.000022  0.000147  0.000002  0.000035  0.000032
# TCGA-GM-A2D9  0.000043  0.000019  0.000085  0.000002  0.000016  0.000022
# TCGA-GM-A2DC  0.000033  0.000013  0.000082  0.000001  0.000013  0.000004
# TCGA-GM-A2DD  0.000031  0.000017  0.000075  0.000002  0.000025  0.000119
# TCGA-GM-A2DF  0.000031  0.000015  0.000161  0.000003  0.000135  0.000007
# TCGA-GM-A2DI  0.000041  0.000071  0.000083  0.000001  0.000017  0.000011
# TCGA-GM-A2DK  0.000031  0.000020  0.000083  0.000001  0.000014  0.000005
# TCGA-GM-A2DM  0.000033  0.000026  0.000111  0.000002  0.000087  0.000032
# TCGA-GM-A2DO  0.000038  0.000013  0.000088  0.000001  0.000027  0.000019
# TCGA-GM-A3NW  0.000035  0.000015  0.000084  0.000001  0.000051  0.000067
# TCGA-GM-A3NY  0.000033  0.000017  0.000071  0.000002  0.000013  0.000004
# TCGA-GM-A3XL  0.000042  0.000020  0.000116  0.000005  0.000024  0.000020
# TCGA-GM-A3XN  0.000053  0.000012  0.000085  0.000001  0.000011  0.000005
# TCGA-GM-A4E0  0.000029  0.000027  0.000080  0.000001  0.000019  0.000005
# TCGA-HN-A2OB  0.000049  0.000011  0.000070  0.000001  0.000046  0.000152
# TCGA-JL-A3YW  0.000056  0.000018  0.000106  0.000002  0.000029  0.000027
# TCGA-JL-A3YX  0.000044  0.000014  0.000096  0.000001  0.000026  0.000006
# TCGA-LL-A440  0.000033  0.000015  0.000075  0.000001  0.000077  0.000193
# TCGA-LL-A50Y  0.000037  0.000013  0.000065  0.000001  0.000012  0.000005
# TCGA-LL-A5YL  0.000028  0.000017  0.000071  0.000004  0.000012  0.000006
# TCGA-LL-A5YM  0.000042  0.000016  0.000094  0.000002  0.000012  0.000005
# TCGA-MS-A51U  0.000059  0.000017  0.000110  0.000126  0.000059  0.000049
# TCGA-OL-A66J  0.000037  0.000018  0.000225  0.000001  0.000053  0.000008
# TCGA-OL-A66K  0.000033  0.000022  0.000089  0.000002  0.000037  0.000009
#
#                   AAAS      AACS     AADAC     AADAT    ...         ZW10  \
# TCGA-A1-A0SD  0.000025  0.000032  0.000006  0.000007    ...     0.000052
# TCGA-A1-A0SH  0.000031  0.000057  0.000003  0.000011    ...     0.000106
# TCGA-A1-A0SJ  0.000038  0.000049  0.000003  0.000009    ...     0.000043
# TCGA-A1-A0SM  0.000028  0.000028  0.000002  0.000007    ...     0.000067
# TCGA-A1-A0SN  0.000045  0.000042  0.000003  0.000009    ...     0.000044
# TCGA-A1-A0SQ  0.000025  0.000065  0.000002  0.000010    ...     0.000074
# TCGA-A2-A04N  0.000029  0.000101  0.000005  0.000019    ...     0.000053
# TCGA-A2-A04P  0.000025  0.000076  0.000003  0.000014    ...     0.000066
# TCGA-A2-A04R  0.000022  0.000035  0.000003  0.000009    ...     0.000111
# TCGA-A2-A04U  0.000048  0.000105  0.000002  0.000011    ...     0.000211
# TCGA-A2-A04W  0.000022  0.000037  0.000002  0.000015    ...     0.000053
# TCGA-A2-A04X  0.000025  0.000038  0.000002  0.000009    ...     0.000038
# TCGA-A2-A0CK  0.000021  0.000074  0.000003  0.000007    ...     0.000073
# TCGA-A2-A0CM  0.000025  0.000079  0.000003  0.000033    ...     0.000075
# TCGA-A2-A0CS  0.000023  0.000057  0.000004  0.000009    ...     0.000042
# TCGA-A2-A0CU  0.000031  0.000100  0.000003  0.000021    ...     0.000052
# TCGA-A2-A0CW  0.000027  0.000039  0.000003  0.000037    ...     0.000057
# TCGA-A2-A0CX  0.000048  0.000074  0.000003  0.000030    ...     0.000043
# TCGA-A2-A0D0  0.000035  0.000083  0.000003  0.000026    ...     0.000054
# TCGA-A2-A0D1  0.000034  0.000055  0.000003  0.000043    ...     0.000040
# TCGA-A2-A0D3  0.000057  0.000042  0.000002  0.000008    ...     0.000067
# TCGA-A2-A0D4  0.000021  0.000096  0.000004  0.000008    ...     0.000091
# TCGA-A2-A0EM  0.000029  0.000050  0.000002  0.000010    ...     0.000033
# TCGA-A2-A0EN  0.000027  0.000052  0.000002  0.000125    ...     0.000035
# TCGA-A2-A0EO  0.000021  0.000089  0.000003  0.000010    ...     0.000044
# TCGA-A2-A0EQ  0.000035  0.000049  0.000003  0.000018    ...     0.000103
# TCGA-A2-A0ER  0.000021  0.000150  0.000003  0.000009    ...     0.000034
# TCGA-A2-A0ES  0.000042  0.002110  0.000006  0.000017    ...     0.000086
# TCGA-A2-A0EU  0.000019  0.000035  0.009391  0.000016    ...     0.000029
# TCGA-A2-A0EV  0.000027  0.000143  0.000003  0.000014    ...     0.000047
# ...                ...       ...       ...       ...    ...          ...
# TCGA-EW-A2FS  0.000136  0.000040  0.000002  0.000007    ...     0.000062
# TCGA-EW-A2FV  0.000020  0.000061  0.000004  0.000014    ...     0.000039
# TCGA-EW-A2FW  0.000026  0.000079  0.000003  0.000011    ...     0.000047
# TCGA-EW-A3E8  0.000045  0.000035  0.000002  0.000035    ...     0.000048
# TCGA-EW-A3U0  0.000056  0.000056  0.000003  0.000009    ...     0.000047
# TCGA-GI-A2C8  0.000025  0.000216  0.000002  0.000016    ...     0.000054
# TCGA-GI-A2C9  0.000026  0.000084  0.000002  0.000010    ...     0.000071
# TCGA-GM-A2D9  0.000059  0.000047  0.000003  0.000009    ...     0.000066
# TCGA-GM-A2DC  0.000026  0.000037  0.000002  0.000010    ...     0.000037
# TCGA-GM-A2DD  0.000025  0.000068  0.000003  0.000008    ...     0.000055
# TCGA-GM-A2DF  0.000021  0.000032  0.000002  0.000009    ...     0.000038
# TCGA-GM-A2DI  0.000029  0.000053  0.000003  0.000013    ...     0.000068
# TCGA-GM-A2DK  0.000023  0.000048  0.000002  0.000008    ...     0.000045
# TCGA-GM-A2DM  0.000107  0.000047  0.000003  0.000011    ...     0.000067
# TCGA-GM-A2DO  0.000026  0.000050  0.000002  0.000023    ...     0.000070
# TCGA-GM-A3NW  0.000025  0.000047  0.000003  0.000013    ...     0.000045
# TCGA-GM-A3NY  0.000037  0.000077  0.000003  0.000036    ...     0.000043
# TCGA-GM-A3XL  0.000033  0.000114  0.000003  0.000017    ...     0.000058
# TCGA-GM-A3XN  0.000195  0.000028  0.000003  0.000008    ...     0.000061
# TCGA-GM-A4E0  0.000020  0.000093  0.000005  0.000015    ...     0.000037
# TCGA-HN-A2OB  0.000018  0.000054  0.000002  0.000009    ...     0.000030
# TCGA-JL-A3YW  0.000025  0.000111  0.000002  0.000029    ...     0.000051
# TCGA-JL-A3YX  0.000030  0.000112  0.000002  0.000013    ...     0.000071
# TCGA-LL-A440  0.000039  0.000044  0.000005  0.000008    ...     0.000126
# TCGA-LL-A50Y  0.000026  0.000030  0.000002  0.000007    ...     0.000057
# TCGA-LL-A5YL  0.000025  0.000091  0.000003  0.000042    ...     0.000043
# TCGA-LL-A5YM  0.000030  0.000053  0.000002  0.000022    ...     0.000114
# TCGA-MS-A51U  0.000042  0.000068  0.000002  0.000008    ...     0.000051
# TCGA-OL-A66J  0.000033  0.000041  0.000002  0.000010    ...     0.000051
# TCGA-OL-A66K  0.000034  0.000052  0.000004  0.000009    ...     0.000049
#
#                 ZWILCH     ZWINT          ZXDA      ZXDC        ZYG11A  \
# TCGA-A1-A0SD  0.000022  0.000049  1.126389e-06  0.000024  1.872107e-07
# TCGA-A1-A0SH  0.000043  0.000069  6.695249e-07  0.000010  1.847108e-07
# TCGA-A1-A0SJ  0.000017  0.000044  1.418609e-06  0.000035  1.210918e-07
# TCGA-A1-A0SM  0.000048  0.000076  8.085955e-07  0.000014  7.229341e-08
# TCGA-A1-A0SN  0.000025  0.000058  6.288759e-07  0.000009  1.964273e-07
# TCGA-A1-A0SQ  0.000054  0.000037  5.526172e-07  0.000009  7.687999e-08
# TCGA-A2-A04N  0.000024  0.000056  8.111314e-07  0.000012  1.263387e-07
# TCGA-A2-A04P  0.000039  0.000059  1.655668e-06  0.000011  9.410530e-08
# TCGA-A2-A04R  0.000016  0.000051  5.913089e-07  0.000008  9.475785e-08
# TCGA-A2-A04U  0.000046  0.000053  6.024080e-07  0.000008  7.445288e-08
# TCGA-A2-A04W  0.000032  0.000076  6.579808e-07  0.000009  2.269905e-07
# TCGA-A2-A04X  0.000016  0.000162  6.050234e-07  0.000008  9.677623e-08
# TCGA-A2-A0CK  0.000055  0.000034  6.315525e-07  0.000008  5.629274e-08
# TCGA-A2-A0CM  0.000053  0.000172  7.185317e-07  0.000012  1.257902e-07
# TCGA-A2-A0CS  0.000014  0.000034  6.125804e-07  0.000009  1.473359e-07
# TCGA-A2-A0CU  0.000026  0.000081  6.355479e-07  0.000009  1.355266e-07
# TCGA-A2-A0CW  0.000035  0.000066  6.127243e-07  0.000009  1.085500e-07
# TCGA-A2-A0CX  0.000021  0.000043  6.724014e-07  0.000010  1.443068e-07
# TCGA-A2-A0D0  0.000025  0.000082  8.042022e-07  0.000010  1.641504e-07
# TCGA-A2-A0D1  0.000019  0.000046  9.805549e-07  0.000008  6.810824e-08
# TCGA-A2-A0D3  0.000017  0.000045  6.839105e-07  0.000010  6.683059e-08
# TCGA-A2-A0D4  0.000018  0.000042  7.826299e-07  0.000013  1.655276e-07
# TCGA-A2-A0EM  0.000014  0.000038  6.146601e-07  0.000008  9.987720e-08
# TCGA-A2-A0EN  0.000015  0.000038  8.591497e-07  0.000018  5.686469e-08
# TCGA-A2-A0EO  0.000023  0.000058  2.596975e-06  0.000074  1.661752e-07
# TCGA-A2-A0EQ  0.000056  0.000070  8.591979e-07  0.000012  1.520991e-07
# TCGA-A2-A0ER  0.000015  0.000035  5.268445e-07  0.000008  1.010333e-07
# TCGA-A2-A0ES  0.000057  0.000316  6.828490e-07  0.000010  2.023251e-07
# TCGA-A2-A0EU  0.000013  0.000172  7.155141e-07  0.000013  2.446031e-07
# TCGA-A2-A0EV  0.000021  0.000046  8.748262e-07  0.000017  1.251933e-07
# ...                ...       ...           ...       ...           ...
# TCGA-EW-A2FS  0.000039  0.000050  7.203179e-07  0.000012  6.955922e-08
# TCGA-EW-A2FV  0.000015  0.000042  7.959873e-07  0.000014  9.555368e-08
# TCGA-EW-A2FW  0.000019  0.001509  5.169285e-07  0.000007  7.749245e-08
# TCGA-EW-A3E8  0.000018  0.000046  9.481404e-07  0.000010  1.468236e-07
# TCGA-EW-A3U0  0.000019  0.000075  1.331247e-05  0.000012  9.913040e-08
# TCGA-GI-A2C8  0.000029  0.000050  9.672239e-07  0.000020  1.295262e-07
# TCGA-GI-A2C9  0.000074  0.000093  7.814375e-07  0.000009  1.276120e-07
# TCGA-GM-A2D9  0.000032  0.000062  6.116347e-07  0.000008  1.065232e-07
# TCGA-GM-A2DC  0.000016  0.000037  5.891318e-07  0.000008  1.066142e-07
# TCGA-GM-A2DD  0.000014  0.000056  7.685718e-07  0.000010  8.489201e-08
# TCGA-GM-A2DF  0.000020  0.000318  6.489096e-07  0.000012  4.797230e-08
# TCGA-GM-A2DI  0.000023  0.000040  6.007732e-07  0.000007  2.161490e-07
# TCGA-GM-A2DK  0.000023  0.000053  7.670141e-07  0.000011  5.198958e-08
# TCGA-GM-A2DM  0.000038  0.000195  7.278519e-05  0.002421  1.456714e-07
# TCGA-GM-A2DO  0.000028  0.000043  7.387377e-07  0.000011  7.958279e-08
# TCGA-GM-A3NW  0.000026  0.000045  8.394444e-07  0.000016  1.241812e-07
# TCGA-GM-A3NY  0.000016  0.000036  5.794697e-07  0.000008  7.108172e-08
# TCGA-GM-A3XL  0.000028  0.000052  6.571540e-07  0.000009  1.539337e-07
# TCGA-GM-A3XN  0.000020  0.000053  6.585938e-07  0.000008  6.806062e-08
# TCGA-GM-A4E0  0.000014  0.000045  7.390051e-07  0.000008  4.788332e-08
# TCGA-HN-A2OB  0.000014  0.000035  5.847663e-07  0.000011  5.408615e-08
# TCGA-JL-A3YW  0.000020  0.000165  1.564040e-06  0.000014  1.400414e-07
# TCGA-JL-A3YX  0.000037  0.000068  1.058014e-06  0.000011  1.186102e-07
# TCGA-LL-A440  0.000103  0.000045  5.777979e-07  0.000007  1.122196e-07
# TCGA-LL-A50Y  0.000016  0.000068  5.485838e-07  0.000007  8.307858e-08
# TCGA-LL-A5YL  0.000020  0.000300  5.996545e-07  0.000008  1.362679e-07
# TCGA-LL-A5YM  0.000068  0.000097  6.148161e-07  0.000007  1.260370e-07
# TCGA-MS-A51U  0.000032  0.000056  7.728217e-07  0.000011  1.720393e-07
# TCGA-OL-A66J  0.000024  0.000042  7.630775e-07  0.000010  2.056962e-07
# TCGA-OL-A66K  0.000018  0.000052  8.272592e-07  0.000010  1.605753e-07
#
#                 ZYG11B       ZYX     ZZEF1      ZZZ3
# TCGA-A1-A0SD  0.000003  0.000191  0.000012  0.000025
# TCGA-A1-A0SH  0.000005  0.000038  0.000010  0.000017
# TCGA-A1-A0SJ  0.000004  0.000041  0.000016  0.000024
# TCGA-A1-A0SM  0.000004  0.000045  0.000008  0.000021
# TCGA-A1-A0SN  0.000005  0.000045  0.000009  0.000017
# TCGA-A1-A0SQ  0.000003  0.000034  0.000010  0.000018
# TCGA-A2-A04N  0.000007  0.000044  0.000022  0.000028
# TCGA-A2-A04P  0.000004  0.000043  0.000013  0.000022
# TCGA-A2-A04R  0.000025  0.000059  0.000013  0.000050
# TCGA-A2-A04U  0.000005  0.000087  0.000011  0.000023
# TCGA-A2-A04W  0.000003  0.000041  0.000010  0.000019
# TCGA-A2-A04X  0.000005  0.000042  0.000012  0.000023
# TCGA-A2-A0CK  0.000003  0.000086  0.000008  0.000025
# TCGA-A2-A0CM  0.000004  0.000039  0.000010  0.000017
# TCGA-A2-A0CS  0.000005  0.000036  0.000010  0.000022
# TCGA-A2-A0CU  0.000006  0.000043  0.000771  0.000023
# TCGA-A2-A0CW  0.000012  0.000042  0.000012  0.000020
# TCGA-A2-A0CX  0.000008  0.000058  0.000011  0.001272
# TCGA-A2-A0D0  0.000006  0.000048  0.000025  0.000070
# TCGA-A2-A0D1  0.000005  0.000043  0.000011  0.000043
# TCGA-A2-A0D3  0.000018  0.000040  0.000009  0.000024
# TCGA-A2-A0D4  0.000003  0.000047  0.000012  0.000021
# TCGA-A2-A0EM  0.000006  0.000053  0.000007  0.000107
# TCGA-A2-A0EN  0.000004  0.000038  0.000011  0.000028
# TCGA-A2-A0EO  0.000005  0.000068  0.000011  0.000020
# TCGA-A2-A0EQ  0.000007  0.000041  0.000010  0.000026
# TCGA-A2-A0ER  0.000003  0.000035  0.000016  0.000017
# TCGA-A2-A0ES  0.000005  0.000039  0.000013  0.000029
# TCGA-A2-A0EU  0.000004  0.000042  0.000016  0.000015
# TCGA-A2-A0EV  0.000006  0.000052  0.000041  0.000020
# ...                ...       ...       ...       ...
# TCGA-EW-A2FS  0.000005  0.000037  0.000008  0.000019
# TCGA-EW-A2FV  0.000005  0.000052  0.000020  0.000021
# TCGA-EW-A2FW  0.000007  0.000039  0.000022  0.000021
# TCGA-EW-A3E8  0.000017  0.000052  0.000010  0.000023
# TCGA-EW-A3U0  0.000004  0.000044  0.000012  0.002515
# TCGA-GI-A2C8  0.000005  0.000045  0.000013  0.000022
# TCGA-GI-A2C9  0.000005  0.000037  0.000013  0.000020
# TCGA-GM-A2D9  0.000005  0.000045  0.000016  0.000047
# TCGA-GM-A2DC  0.000015  0.000046  0.000018  0.000020
# TCGA-GM-A2DD  0.000006  0.000043  0.000009  0.000023
# TCGA-GM-A2DF  0.000006  0.000039  0.000016  0.000017
# TCGA-GM-A2DI  0.000005  0.000209  0.000010  0.000022
# TCGA-GM-A2DK  0.000004  0.000039  0.000008  0.000021
# TCGA-GM-A2DM  0.000005  0.000037  0.000028  0.000022
# TCGA-GM-A2DO  0.000007  0.000052  0.000079  0.000039
# TCGA-GM-A3NW  0.000004  0.000046  0.000010  0.000021
# TCGA-GM-A3NY  0.000004  0.000036  0.000011  0.000018
# TCGA-GM-A3XL  0.000006  0.000048  0.000025  0.000026
# TCGA-GM-A3XN  0.000004  0.000086  0.000010  0.000019
# TCGA-GM-A4E0  0.000004  0.000089  0.000013  0.000029
# TCGA-HN-A2OB  0.000003  0.000035  0.000016  0.000025
# TCGA-JL-A3YW  0.000006  0.000048  0.000027  0.000040
# TCGA-JL-A3YX  0.000004  0.000043  0.000008  0.000024
# TCGA-LL-A440  0.000005  0.000036  0.000010  0.000060
# TCGA-LL-A50Y  0.000003  0.000062  0.000172  0.000029
# TCGA-LL-A5YL  0.000005  0.000041  0.000011  0.000018
# TCGA-LL-A5YM  0.000004  0.000039  0.000024  0.000021
# TCGA-MS-A51U  0.000004  0.000041  0.000010  0.000021
# TCGA-OL-A66J  0.000006  0.000224  0.000011  0.000037
# TCGA-OL-A66K  0.000022  0.000060  0.000011  0.000062
#
# [511 rows x 19987 columns]
